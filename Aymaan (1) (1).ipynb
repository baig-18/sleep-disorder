# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import numpy as np

from keras.models import Sequential
from keras.layers import LSTM
from tensorflow.keras.layers import Dense, Embedding, Conv1D, MaxPool1D, Dropout,LSTM, Input
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from time import time
from keras.layers import LeakyReLU, PReLU
import tensorflow as tf
from tensorflow.python.client import device_lib
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv(r"/content/drive/MyDrive/sleep_prediction.csv")
df
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 0          277    Male   49     Doctor             8.1                 9
# 1           40    Male   31     Doctor             7.6                 7
# 2           74    Male   33     Doctor             6.1                 6
# 3          287  Female   50      Nurse             6.0                 6
# 4          171    Male   41     Lawyer             7.7                 8
# ..         ...     ...  ...        ...             ...               ...
# 995         48    Male   31     Doctor             7.8                 7
# 996        348  Female   57      Nurse             8.2                 9
# 997        231  Female   44    Teacher             6.6                 7
# 998        186  Female   42    Teacher             6.8                 6
# 999         15    Male   29     Doctor             6.0                 6
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                         85             3        Obese         139/91
# 1                         75             6       Normal         120/80
# 2                         30             8       Normal         125/80
# 3                         90             8   Overweight         140/95
# 4                         90             5       Normal         130/85
# ..                       ...           ...          ...            ...
# 995                       75             6       Normal         120/80
# 996                       75             3   Overweight         140/95
# 997                       45             4   Overweight         135/90
# 998                       45             7   Overweight         130/85
# 999                       30             8       Normal         120/80
#
#      Heart Rate  Daily Steps Sleep Disorder
# 0            86         3700    Sleep Apnea
# 1            70         8000            NaN
# 2            72         5000            NaN
# 3            75        10000    Sleep Apnea
# 4            70         8000            NaN
# ..          ...          ...            ...
# 995          70         8000            NaN
# 996          68         7000    Sleep Apnea
# 997          65         6000       Insomnia
# 998          78         5000    Sleep Apnea
# 999          70         8000            NaN
#
# [1000 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Age                      1000 non-null   int64
#  3   Occupation               1000 non-null   object
#  4   Sleep Duration           1000 non-null   float64
#  5   Quality of Sleep         1000 non-null   int64
#  6   Physical Activity Level  1000 non-null   int64
#  7   Stress Level             1000 non-null   int64
#  8   BMI Category             1000 non-null   object
#  9   Blood Pressure           1000 non-null   object
#  10  Heart Rate               1000 non-null   int64
#  11  Daily Steps              1000 non-null   int64
#  12  Sleep Disorder           413 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 101.7+ KB

# %%
df.describe()
# Out:
#          Person ID          Age  Sleep Duration  Quality of Sleep  \
# count  1000.000000  1000.000000     1000.000000        1000.00000
# mean    193.407000    42.659000        7.152900           7.34000
# std     108.225941     8.762163        0.805593           1.23285
# min       1.000000    27.000000        5.800000           4.00000
# 25%     103.000000    36.000000        6.500000           6.00000
# 50%     195.000000    43.000000        7.200000           7.00000
# 75%     288.000000    50.000000        7.800000           8.00000
# max     373.000000    59.000000        8.500000           9.00000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count              1000.000000   1000.000000   1000.0000   1000.000000
# mean                 59.430000      5.346000     70.2010   6840.100000
# std                  21.201288      1.793181      4.1233   1615.230931
# min                  30.000000      3.000000     65.0000   3000.000000
# 25%                  45.000000      4.000000     68.0000   5600.000000
# 50%                  60.000000      5.000000     70.0000   7000.000000
# 75%                  75.000000      7.000000     72.0000   8000.000000
# max                  90.000000      8.000000     86.0000  10000.000000

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             587
# dtype: int64

# %%
df["Sleep Disorder"].unique()
# Out:
# array(['Sleep Apnea', nan, 'Insomnia'], dtype=object)

# %%
df = df.drop(columns=["Person ID"])

# %%
df
# Out:
#      Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   49     Doctor             8.1                 9
# 1      Male   31     Doctor             7.6                 7
# 2      Male   33     Doctor             6.1                 6
# 3    Female   50      Nurse             6.0                 6
# 4      Male   41     Lawyer             7.7                 8
# ..      ...  ...        ...             ...               ...
# 995    Male   31     Doctor             7.8                 7
# 996  Female   57      Nurse             8.2                 9
# 997  Female   44    Teacher             6.6                 7
# 998  Female   42    Teacher             6.8                 6
# 999    Male   29     Doctor             6.0                 6
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                         85             3        Obese         139/91
# 1                         75             6       Normal         120/80
# 2                         30             8       Normal         125/80
# 3                         90             8   Overweight         140/95
# 4                         90             5       Normal         130/85
# ..                       ...           ...          ...            ...
# 995                       75             6       Normal         120/80
# 996                       75             3   Overweight         140/95
# 997                       45             4   Overweight         135/90
# 998                       45             7   Overweight         130/85
# 999                       30             8       Normal         120/80
#
#      Heart Rate  Daily Steps Sleep Disorder
# 0            86         3700    Sleep Apnea
# 1            70         8000            NaN
# 2            72         5000            NaN
# 3            75        10000    Sleep Apnea
# 4            70         8000            NaN
# ..          ...          ...            ...
# 995          70         8000            NaN
# 996          68         7000    Sleep Apnea
# 997          65         6000       Insomnia
# 998          78         5000    Sleep Apnea
# 999          70         8000            NaN
#
# [1000 rows x 12 columns]

# %%
df.shape
# Out:
# (1000, 12)

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array(['Doctor', 'Nurse', 'Lawyer', 'Salesperson', 'Engineer',
#        'Scientist', 'Manager', 'Accountant', 'Software Engineer',
#        'Teacher', 'Sales Representative'], dtype=object)

# %%
df["Sleep Duration"].unique()
# Out:
# array([8.1, 7.6, 6.1, 6. , 7.7, 8.2, 6.5, 7.8, 6.2, 6.4, 7.4, 6.3, 7.2,
#        8.3, 6.9, 8. , 7.1, 5.9, 6.6, 7.3, 8.5, 7.5, 6.8, 8.4, 6.7, 7.9,
#        5.8])

# %%
df["BMI Category"].unique()
# Out:
# array(['Obese', 'Normal', 'Overweight', 'Normal Weight'], dtype=object)

# %%
df['Gender'] = df['Gender'].astype('category').cat.codes

# %%
df['Gender'] = df['Gender'].astype('category').cat.codes
df['Age'] = df['Age'].astype('category').cat.codes
df['Occupation'] = df['Occupation'].astype('category').cat.codes
df['BMI Category'] = df['BMI Category'].astype('category').cat.codes
df['Blood Pressure'] = df['Blood Pressure'].astype('category').cat.codes
df['Sleep Disorder'] = df['Sleep Disorder'].astype('category').cat.codes

# %%
df.corr()
# Out:
#                            Gender       Age  Occupation  Sleep Duration  \
# Gender                   1.000000 -0.573286   -0.213156       -0.143291
# Age                     -0.573286  1.000000    0.234119        0.394585
# Occupation              -0.213156  0.234119    1.000000       -0.350710
# Sleep Duration          -0.143291  0.394585   -0.350710        1.000000
# Quality of Sleep        -0.294277  0.509758   -0.304057        0.893700
# Physical Activity Level  0.001336  0.197022   -0.105405        0.195525
# Stress Level             0.402557 -0.464260    0.056916       -0.827509
# BMI Category            -0.334469  0.487035    0.705741       -0.377724
# Blood Pressure          -0.174298  0.561980    0.549888       -0.172554
# Heart Rate               0.208931 -0.273029    0.081050       -0.544432
# Daily Steps              0.008115  0.044340   -0.126065       -0.059605
# Sleep Disorder          -0.382673  0.486132    0.474942       -0.248230
#
#                          Quality of Sleep  Physical Activity Level  \
# Gender                          -0.294277                 0.001336
# Age                              0.509758                 0.197022
# Occupation                      -0.304057                -0.105405
# Sleep Duration                   0.893700                 0.195525
# Quality of Sleep                 1.000000                 0.196493
# Physical Activity Level          0.196493                 1.000000
# Stress Level                    -0.903160                -0.031616
# BMI Category                    -0.317372                 0.084271
# Blood Pressure                  -0.132931                 0.301661
# Heart Rate                      -0.676471                 0.134471
# Daily Steps                      0.018130                 0.770584
# Sleep Disorder                  -0.216694                 0.248861
#
#                          Stress Level  BMI Category  Blood Pressure  \
# Gender                       0.402557     -0.334469       -0.174298
# Age                         -0.464260      0.487035        0.561980
# Occupation                   0.056916      0.705741        0.549888
# Sleep Duration              -0.827509     -0.377724       -0.172554
# Quality of Sleep            -0.903160     -0.317372       -0.132931
# Physical Activity Level     -0.031616      0.084271        0.301661
# Stress Level                 1.000000      0.176190        0.114190
# BMI Category                 0.176190      1.000000        0.712389
# Blood Pressure               0.114190      0.712389        1.000000
# Heart Rate                   0.673594      0.318444        0.288857
# Daily Steps                  0.189709     -0.017528        0.132525
# Sleep Disorder               0.164182      0.755942        0.744857
#
#                          Heart Rate  Daily Steps  Sleep Disorder
# Gender                     0.208931     0.008115       -0.382673
# Age                       -0.273029     0.044340        0.486132
# Occupation                 0.081050    -0.126065        0.474942
# Sleep Duration            -0.544432    -0.059605       -0.248230
# Quality of Sleep          -0.676471     0.018130       -0.216694
# Physical Activity Level    0.134471     0.770584        0.248861
# Stress Level               0.673594     0.189709        0.164182
# BMI Category               0.318444    -0.017528        0.755942
# Blood Pressure             0.288857     0.132525        0.744857
# Heart Rate                 1.000000    -0.035780        0.391917
# Daily Steps               -0.035780     1.000000        0.121824
# Sleep Disorder             0.391917     0.121824        1.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap of Correlations',fontsize=15)
plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Gender
# 0    505
# 1    495
# Name: count, dtype: int64

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# 5     206
# 2     179
# 1     175
# 3     129
# 10     99
# 0      92
# 7      89
# 8      15
# 9       8
# 4       4
# 6       4
# Name: count, dtype: int64

# %%
df["BMI Category"].value_counts()
# Out:
# BMI Category
# 0    514
# 3    412
# 1     51
# 2     23
# Name: count, dtype: int64

# %%
df["Sleep Disorder"].value_counts()
# Out:
# Sleep Disorder
# 0    587
# 2    215
# 1    198
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.despine(left=True)
sns.scatterplot(x='Age', y='Sleep Duration', hue = 'Sleep Disorder', data=df)
plt.show()

# %%
sns.countplot(x=df["Age"],hue=df['Sleep Disorder'])
plt.show()

# %%
sns.countplot(x=df["Occupation"],hue=df['Sleep Disorder'])
plt.show()

# %%
sns.countplot(x=df["Gender"],hue=df['Sleep Disorder'])
plt.show()

# %%
df.columns.to_list()
# Out:
# ['Gender',
#  'Age',
#  'Occupation',
#  'Sleep Duration',
#  'Quality of Sleep',
#  'Physical Activity Level',
#  'Stress Level',
#  'BMI Category',
#  'Blood Pressure',
#  'Heart Rate',
#  'Daily Steps',
#  'Sleep Disorder']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])
df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1   20           1             8.1                 9
# 1         1    4           1             7.6                 7
# 2         1    6           1             6.1                 6
# 3         0   21           5             6.0                 6
# 4         1   14           3             7.7                 8
# ..      ...  ...         ...             ...               ...
# 995       1    4           1             7.8                 7
# 996       0   28           5             8.2                 9
# 997       0   17          10             6.6                 7
# 998       0   15          10             6.8                 6
# 999       1    2           1             6.0                 6
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 0                         85             3             2              21
# 1                         75             6             0               6
# 2                         30             8             0               9
# 3                         90             8             3              23
# 4                         90             5             0              15
# ..                       ...           ...           ...             ...
# 995                       75             6             0               6
# 996                       75             3             3              23
# 997                       45             4             3              20
# 998                       45             7             3              15
# 999                       30             8             0               6
#
#      Heart Rate  Daily Steps  Sleep Disorder
# 0            86         3700               2
# 1            70         8000               0
# 2            72         5000               0
# 3            75        10000               2
# 4            70         8000               0
# ..          ...          ...             ...
# 995          70         8000               0
# 996          68         7000               2
# 997          65         6000               1
# 998          78         5000               2
# 999          70         8000               0
#
# [1000 rows x 12 columns]

# %%
df['Occupation']=le.fit_transform(df['Occupation'])
df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1   20           1             8.1                 9
# 1         1    4           1             7.6                 7
# 2         1    6           1             6.1                 6
# 3         0   21           5             6.0                 6
# 4         1   14           3             7.7                 8
# ..      ...  ...         ...             ...               ...
# 995       1    4           1             7.8                 7
# 996       0   28           5             8.2                 9
# 997       0   17          10             6.6                 7
# 998       0   15          10             6.8                 6
# 999       1    2           1             6.0                 6
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 0                         85             3             2              21
# 1                         75             6             0               6
# 2                         30             8             0               9
# 3                         90             8             3              23
# 4                         90             5             0              15
# ..                       ...           ...           ...             ...
# 995                       75             6             0               6
# 996                       75             3             3              23
# 997                       45             4             3              20
# 998                       45             7             3              15
# 999                       30             8             0               6
#
#      Heart Rate  Daily Steps  Sleep Disorder
# 0            86         3700               2
# 1            70         8000               0
# 2            72         5000               0
# 3            75        10000               2
# 4            70         8000               0
# ..          ...          ...             ...
# 995          70         8000               0
# 996          68         7000               2
# 997          65         6000               1
# 998          78         5000               2
# 999          70         8000               0
#
# [1000 rows x 12 columns]

# %%
df['BMI Category']=le.fit_transform(df['BMI Category'])
df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1   20           1             8.1                 9
# 1         1    4           1             7.6                 7
# 2         1    6           1             6.1                 6
# 3         0   21           5             6.0                 6
# 4         1   14           3             7.7                 8
# ..      ...  ...         ...             ...               ...
# 995       1    4           1             7.8                 7
# 996       0   28           5             8.2                 9
# 997       0   17          10             6.6                 7
# 998       0   15          10             6.8                 6
# 999       1    2           1             6.0                 6
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 0                         85             3             2              21
# 1                         75             6             0               6
# 2                         30             8             0               9
# 3                         90             8             3              23
# 4                         90             5             0              15
# ..                       ...           ...           ...             ...
# 995                       75             6             0               6
# 996                       75             3             3              23
# 997                       45             4             3              20
# 998                       45             7             3              15
# 999                       30             8             0               6
#
#      Heart Rate  Daily Steps  Sleep Disorder
# 0            86         3700               2
# 1            70         8000               0
# 2            72         5000               0
# 3            75        10000               2
# 4            70         8000               0
# ..          ...          ...             ...
# 995          70         8000               0
# 996          68         7000               2
# 997          65         6000               1
# 998          78         5000               2
# 999          70         8000               0
#
# [1000 rows x 12 columns]

# %%
df['Sleep Disorder']=le.fit_transform(df['Sleep Disorder'])
df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1   20           1             8.1                 9
# 1         1    4           1             7.6                 7
# 2         1    6           1             6.1                 6
# 3         0   21           5             6.0                 6
# 4         1   14           3             7.7                 8
# ..      ...  ...         ...             ...               ...
# 995       1    4           1             7.8                 7
# 996       0   28           5             8.2                 9
# 997       0   17          10             6.6                 7
# 998       0   15          10             6.8                 6
# 999       1    2           1             6.0                 6
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 0                         85             3             2              21
# 1                         75             6             0               6
# 2                         30             8             0               9
# 3                         90             8             3              23
# 4                         90             5             0              15
# ..                       ...           ...           ...             ...
# 995                       75             6             0               6
# 996                       75             3             3              23
# 997                       45             4             3              20
# 998                       45             7             3              15
# 999                       30             8             0               6
#
#      Heart Rate  Daily Steps  Sleep Disorder
# 0            86         3700               2
# 1            70         8000               0
# 2            72         5000               0
# 3            75        10000               2
# 4            70         8000               0
# ..          ...          ...             ...
# 995          70         8000               0
# 996          68         7000               2
# 997          65         6000               1
# 998          78         5000               2
# 999          70         8000               0
#
# [1000 rows x 12 columns]

# %%
df['Blood Pressure']=le.fit_transform(df['Blood Pressure'])
df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1   20           1             8.1                 9
# 1         1    4           1             7.6                 7
# 2         1    6           1             6.1                 6
# 3         0   21           5             6.0                 6
# 4         1   14           3             7.7                 8
# ..      ...  ...         ...             ...               ...
# 995       1    4           1             7.8                 7
# 996       0   28           5             8.2                 9
# 997       0   17          10             6.6                 7
# 998       0   15          10             6.8                 6
# 999       1    2           1             6.0                 6
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 0                         85             3             2              21
# 1                         75             6             0               6
# 2                         30             8             0               9
# 3                         90             8             3              23
# 4                         90             5             0              15
# ..                       ...           ...           ...             ...
# 995                       75             6             0               6
# 996                       75             3             3              23
# 997                       45             4             3              20
# 998                       45             7             3              15
# 999                       30             8             0               6
#
#      Heart Rate  Daily Steps  Sleep Disorder
# 0            86         3700               2
# 1            70         8000               0
# 2            72         5000               0
# 3            75        10000               2
# 4            70         8000               0
# ..          ...          ...             ...
# 995          70         8000               0
# 996          68         7000               2
# 997          65         6000               1
# 998          78         5000               2
# 999          70         8000               0
#
# [1000 rows x 12 columns]

# %%
df["Sleep Disorder"].value_counts()
# Out:
# Sleep Disorder
# 0    587
# 2    215
# 1    198
# Name: count, dtype: int64

# %%
from sklearn.utils import resample
# Separate majority and minority classes
df_majority = df[df['Sleep Disorder']== 1]
df_minority = df[df['Sleep Disorder']== 2]
df_minority1 = df[df['Sleep Disorder']== 0]

# Downsample majority class and upsample the minority class
df_minority_upsampled = resample(df_minority, replace=True,n_samples=300,random_state=100)
df_minority1_upsampled = resample(df_minority1, replace=True,n_samples=300,random_state=100)
df_majority_downsampled = resample(df_majority, replace=True,n_samples=300,random_state=100)

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_minority_upsampled,df_minority1_upsampled,df_majority_downsampled])

# Display new class counts
df_balanced['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# 2    300
# 0    300
# 1    300
# Name: count, dtype: int64

# %%
df=df_balanced
df
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 24        0    3           5             6.4                 5
# 110       0   21           5             6.0                 6
# 358       0   21           5             6.1                 6
# 514       0   20           5             6.1                 6
# 462       0   21           5             6.0                 6
# ..      ...  ...         ...             ...               ...
# 417       1   16           7             6.5                 6
# 396       1   17           7             6.4                 6
# 60        1   16           7             6.5                 6
# 321       1   17           7             6.3                 6
# 653       0   23           0             6.5                 7
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 24                        35             7             1              16
# 110                       90             8             3              23
# 358                       90             8             3              23
# 514                       90             8             3              23
# 462                       90             8             3              23
# ..                       ...           ...           ...             ...
# 417                       45             7             3              15
# 396                       45             7             3              15
# 60                        45             7             3              15
# 321                       45             7             3              15
# 653                       45             7             3              15
#
#      Heart Rate  Daily Steps  Sleep Disorder
# 24           78         4100               2
# 110          75        10000               2
# 358          75        10000               2
# 514          75        10000               2
# 462          75        10000               2
# ..          ...          ...             ...
# 417          72         6000               1
# 396          72         6000               1
# 60           72         6000               1
# 321          72         6000               1
# 653          72         6000               1
#
# [900 rows x 12 columns]

# %%
x = df.drop(columns=['Sleep Disorder'])
y = df['Sleep Disorder']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=100)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train.shape, y_train.shape
# Out:
# ((675, 11), (675,))

# %%
x_test.shape, y_test.shape
# Out:
# ((225, 11), (225,))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# %%
from sklearn.ensemble import RandomForestClassifier

dept = [1, 5, 10, 50, 100, 500, 1000]
n_estimators =  [20, 40, 60, 80, 100, 120]

param_grid={'n_estimators':n_estimators , 'max_depth':dept}
clf = RandomForestClassifier()
model = GridSearchCV(clf,param_grid,scoring='accuracy',n_jobs=-1,cv=5)
model.fit(x_train,y_train)
print("optimal n_estimators",model.best_estimator_.n_estimators)
print("optimal max_depth",model.best_estimator_.max_depth)
optimal_max_depth = model.best_estimator_.max_depth
optimal_n_estimators = model.best_estimator_.n_estimators
# Out:
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# optimal n_estimators 20
# optimal max_depth 500

# %%
from sklearn.metrics import accuracy_score
#training our model for max_depth=500,n_estimators = 60
clf = RandomForestClassifier(max_depth = optimal_max_depth,n_estimators = optimal_n_estimators)
clf.fit(x_train,y_train)

pred_test3 =clf.predict(x_test)
test_accuracy3 = accuracy_score(y_test, pred_test3)
pred_train = clf.predict(x_train)
train_accuracy3 =accuracy_score(y_train,pred_train)

print("AUC on Test data is " +str(accuracy_score(y_test,pred_test3)))
print("AUC on Train data is " +str(accuracy_score(y_train,pred_train)))

print("---------------------------")

# Code for drawing seaborn heatmaps
class_names =['None','Sleep Apnea','Insomnia']
df_heatmap = pd.DataFrame(confusion_matrix(y_test, pred_test3.round()), index=class_names, columns=class_names )
fig = plt.figure( )
heatmap = sns.heatmap(df_heatmap, annot=True, fmt="d")
# Out:
# AUC on Test data is 0.9422222222222222
# AUC on Train data is 0.9392592592592592
# ---------------------------

# %%
from sklearn.metrics import accuracy_score, classification_report
class_names = ['None', 'Sleep Apnea', 'Insomnia']
print("Classification Report:")
print(classification_report(y_test, pred_test3, target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         None       0.94      0.93      0.93        68
#  Sleep Apnea       0.92      0.93      0.92        70
#     Insomnia       0.97      0.97      0.97        87
#
#     accuracy                           0.94       225
#    macro avg       0.94      0.94      0.94       225
# weighted avg       0.94      0.94      0.94       225

# %%
#clf.save('rf_sleep.h5')
import joblib
joblib.dump(clf, 'rf_sleep.h5')
# Out:
# ['rf_sleep.h5']

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# Training the Random Forest classifier
clf = RandomForestClassifier(max_depth=optimal_max_depth, n_estimators=optimal_n_estimators)
clf.fit(x_train, y_train)

# Predictions on train and test sets
train_pred = clf.predict(x_train)
test_pred = clf.predict(x_test)

# Accuracy scores
train_accuracy = accuracy_score(y_train, train_pred)
test_accuracy = accuracy_score(y_test, test_pred)

print("Accuracy on Train data is " + str(train_accuracy))
print("Accuracy on Test data is " + str(test_accuracy))
print("---------------------------")

# Training and test accuracy curves
train_accuracies = []
test_accuracies = []
estimators_range = range(1, optimal_n_estimators + 1)  # Adjust range if necessary

for n_estimators in estimators_range:
    clf = RandomForestClassifier(max_depth=optimal_max_depth, n_estimators=n_estimators)
    clf.fit(x_train, y_train)

    train_pred = clf.predict(x_train)
    test_pred = clf.predict(x_test)

    train_accuracy = accuracy_score(y_train, train_pred)
    test_accuracy = accuracy_score(y_test, test_pred)

    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

# Plotting the training and test accuracy curves
plt.figure(figsize=(10, 6))
plt.plot(estimators_range, train_accuracies, label='Train')
plt.plot(estimators_range, test_accuracies, label='Test')
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy')
plt.title('Random Forest Training and Test Accuracy')
plt.legend()
plt.show()
# Out:
# Accuracy on Train data is 0.9392592592592592
# Accuracy on Test data is 0.9422222222222222
# ---------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import numpy as np

from keras.models import Sequential
from keras.layers import LSTM
from tensorflow.keras.layers import Dense, Embedding, Conv1D, MaxPool1D, Dropout,LSTM, Input
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from time import time
from keras.layers import LeakyReLU, PReLU
import tensorflow as tf
from tensorflow.python.client import device_lib
from sklearn.preprocessing import StandardScaler

# %%
from keras.utils import to_categorical

# Convert integer labels to one-hot encoded vectors
y_train = to_categorical(y_train, num_classes=3)
y_test = to_categorical(y_test, num_classes=3)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

model1 = Sequential()
model1.add(Dense(100, activation='relu', input_dim=11))
model1.add(Dropout(0.5))
model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(32, activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(3, activation='softmax'))
model1.compile(optimizer=Adam(lr=0.01),loss='categorical_crossentropy',metrics=['accuracy'])
model1.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 100)               1200
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_11 (Dense)            (None, 64)                6464
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_14 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 14003 (54.70 KB)
# Trainable params: 14003 (54.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
History = model1.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=200, verbose=2)
# Out:
# Epoch 1/50
# 4/4 - 2s - loss: 1.2330 - accuracy: 0.3007 - val_loss: 1.0976 - val_accuracy: 0.2444 - 2s/epoch - 535ms/step
# Epoch 2/50
# 4/4 - 0s - loss: 1.1770 - accuracy: 0.3393 - val_loss: 1.0703 - val_accuracy: 0.6222 - 45ms/epoch - 11ms/step
# Epoch 3/50
# 4/4 - 0s - loss: 1.1253 - accuracy: 0.3704 - val_loss: 1.0465 - val_accuracy: 0.8622 - 43ms/epoch - 11ms/step
# Epoch 4/50
# 4/4 - 0s - loss: 1.1011 - accuracy: 0.3630 - val_loss: 1.0361 - val_accuracy: 0.8622 - 59ms/epoch - 15ms/step
# Epoch 5/50
# 4/4 - 0s - loss: 1.0727 - accuracy: 0.4044 - val_loss: 1.0263 - val_accuracy: 0.8622 - 64ms/epoch - 16ms/step
# Epoch 6/50
# 4/4 - 0s - loss: 1.0560 - accuracy: 0.4370 - val_loss: 1.0124 - val_accuracy: 0.8622 - 62ms/epoch - 16ms/step
# Epoch 7/50
# 4/4 - 0s - loss: 1.0446 - accuracy: 0.4533 - val_loss: 0.9970 - val_accuracy: 0.8400 - 46ms/epoch - 12ms/step
# Epoch 8/50
# 4/4 - 0s - loss: 1.0455 - accuracy: 0.4430 - val_loss: 0.9764 - val_accuracy: 0.8400 - 59ms/epoch - 15ms/step
# Epoch 9/50
# 4/4 - 0s - loss: 1.0430 - accuracy: 0.4385 - val_loss: 0.9522 - val_accuracy: 0.8356 - 49ms/epoch - 12ms/step
# Epoch 10/50
# 4/4 - 0s - loss: 0.9864 - accuracy: 0.5363 - val_loss: 0.9219 - val_accuracy: 0.8356 - 48ms/epoch - 12ms/step
# Epoch 11/50
# 4/4 - 0s - loss: 0.9665 - accuracy: 0.5496 - val_loss: 0.8863 - val_accuracy: 0.8444 - 44ms/epoch - 11ms/step
# Epoch 12/50
# 4/4 - 0s - loss: 0.9464 - accuracy: 0.5733 - val_loss: 0.8441 - val_accuracy: 0.8667 - 46ms/epoch - 11ms/step
# Epoch 13/50
# 4/4 - 0s - loss: 0.9322 - accuracy: 0.5600 - val_loss: 0.7966 - val_accuracy: 0.8711 - 45ms/epoch - 11ms/step
# Epoch 14/50
# 4/4 - 0s - loss: 0.8736 - accuracy: 0.6252 - val_loss: 0.7418 - val_accuracy: 0.8489 - 43ms/epoch - 11ms/step
# Epoch 15/50
# 4/4 - 0s - loss: 0.8672 - accuracy: 0.6326 - val_loss: 0.6835 - val_accuracy: 0.8711 - 45ms/epoch - 11ms/step
# Epoch 16/50
# 4/4 - 0s - loss: 0.8086 - accuracy: 0.6548 - val_loss: 0.6243 - val_accuracy: 0.8711 - 62ms/epoch - 16ms/step
# Epoch 17/50
# 4/4 - 0s - loss: 0.7771 - accuracy: 0.6963 - val_loss: 0.5672 - val_accuracy: 0.8711 - 60ms/epoch - 15ms/step
# Epoch 18/50
# 4/4 - 0s - loss: 0.7742 - accuracy: 0.6593 - val_loss: 0.5154 - val_accuracy: 0.8711 - 60ms/epoch - 15ms/step
# Epoch 19/50
# 4/4 - 0s - loss: 0.7375 - accuracy: 0.7037 - val_loss: 0.4721 - val_accuracy: 0.8711 - 52ms/epoch - 13ms/step
# Epoch 20/50
# 4/4 - 0s - loss: 0.6995 - accuracy: 0.7378 - val_loss: 0.4358 - val_accuracy: 0.8711 - 47ms/epoch - 12ms/step
# Epoch 21/50
# 4/4 - 0s - loss: 0.6529 - accuracy: 0.7556 - val_loss: 0.4071 - val_accuracy: 0.8711 - 46ms/epoch - 11ms/step
# Epoch 22/50
# 4/4 - 0s - loss: 0.6614 - accuracy: 0.7511 - val_loss: 0.3838 - val_accuracy: 0.8711 - 46ms/epoch - 11ms/step
# Epoch 23/50
# 4/4 - 0s - loss: 0.6184 - accuracy: 0.7630 - val_loss: 0.3658 - val_accuracy: 0.8711 - 47ms/epoch - 12ms/step
# Epoch 24/50
# 4/4 - 0s - loss: 0.5818 - accuracy: 0.7837 - val_loss: 0.3528 - val_accuracy: 0.8711 - 76ms/epoch - 19ms/step
# Epoch 25/50
# 4/4 - 0s - loss: 0.6339 - accuracy: 0.7793 - val_loss: 0.3428 - val_accuracy: 0.8978 - 46ms/epoch - 11ms/step
# Epoch 26/50
# 4/4 - 0s - loss: 0.6251 - accuracy: 0.8015 - val_loss: 0.3339 - val_accuracy: 0.8978 - 60ms/epoch - 15ms/step
# Epoch 27/50
# 4/4 - 0s - loss: 0.5663 - accuracy: 0.7807 - val_loss: 0.3258 - val_accuracy: 0.8978 - 60ms/epoch - 15ms/step
# Epoch 28/50
# 4/4 - 0s - loss: 0.5566 - accuracy: 0.8119 - val_loss: 0.3171 - val_accuracy: 0.8978 - 62ms/epoch - 15ms/step
# Epoch 29/50
# 4/4 - 0s - loss: 0.5564 - accuracy: 0.8281 - val_loss: 0.3090 - val_accuracy: 0.9022 - 49ms/epoch - 12ms/step
# Epoch 30/50
# 4/4 - 0s - loss: 0.5876 - accuracy: 0.8015 - val_loss: 0.3014 - val_accuracy: 0.9067 - 64ms/epoch - 16ms/step
# Epoch 31/50
# 4/4 - 0s - loss: 0.6334 - accuracy: 0.8193 - val_loss: 0.3006 - val_accuracy: 0.9067 - 44ms/epoch - 11ms/step
# Epoch 32/50
# 4/4 - 0s - loss: 0.5311 - accuracy: 0.8267 - val_loss: 0.2989 - val_accuracy: 0.9067 - 63ms/epoch - 16ms/step
# Epoch 33/50
# 4/4 - 0s - loss: 0.5104 - accuracy: 0.8281 - val_loss: 0.2955 - val_accuracy: 0.9067 - 61ms/epoch - 15ms/step
# Epoch 34/50
# 4/4 - 0s - loss: 0.5825 - accuracy: 0.8415 - val_loss: 0.2933 - val_accuracy: 0.9067 - 63ms/epoch - 16ms/step
# Epoch 35/50
# 4/4 - 0s - loss: 0.5274 - accuracy: 0.8385 - val_loss: 0.2910 - val_accuracy: 0.9067 - 45ms/epoch - 11ms/step
# Epoch 36/50
# 4/4 - 0s - loss: 0.5254 - accuracy: 0.8474 - val_loss: 0.2874 - val_accuracy: 0.9067 - 61ms/epoch - 15ms/step
# Epoch 37/50
# 4/4 - 0s - loss: 0.5460 - accuracy: 0.8489 - val_loss: 0.2831 - val_accuracy: 0.9067 - 61ms/epoch - 15ms/step
# Epoch 38/50
# 4/4 - 0s - loss: 0.5238 - accuracy: 0.8296 - val_loss: 0.2800 - val_accuracy: 0.9067 - 67ms/epoch - 17ms/step
# Epoch 39/50
# 4/4 - 0s - loss: 0.5171 - accuracy: 0.8385 - val_loss: 0.2751 - val_accuracy: 0.9244 - 83ms/epoch - 21ms/step
# Epoch 40/50
# 4/4 - 0s - loss: 0.4913 - accuracy: 0.8474 - val_loss: 0.2695 - val_accuracy: 0.9244 - 79ms/epoch - 20ms/step
# Epoch 41/50
# 4/4 - 0s - loss: 0.5201 - accuracy: 0.8400 - val_loss: 0.2645 - val_accuracy: 0.9333 - 79ms/epoch - 20ms/step
# Epoch 42/50
# 4/4 - 0s - loss: 0.4782 - accuracy: 0.8578 - val_loss: 0.2605 - val_accuracy: 0.9333 - 80ms/epoch - 20ms/step
# Epoch 43/50
# 4/4 - 0s - loss: 0.4755 - accuracy: 0.8548 - val_loss: 0.2580 - val_accuracy: 0.9244 - 87ms/epoch - 22ms/step
# Epoch 44/50
# 4/4 - 0s - loss: 0.4840 - accuracy: 0.8578 - val_loss: 0.2564 - val_accuracy: 0.9244 - 64ms/epoch - 16ms/step
# Epoch 45/50
# 4/4 - 0s - loss: 0.4862 - accuracy: 0.8548 - val_loss: 0.2554 - val_accuracy: 0.9244 - 76ms/epoch - 19ms/step
# Epoch 46/50
# 4/4 - 0s - loss: 0.4948 - accuracy: 0.8385 - val_loss: 0.2541 - val_accuracy: 0.9244 - 80ms/epoch - 20ms/step
# Epoch 47/50
# 4/4 - 0s - loss: 0.4550 - accuracy: 0.8667 - val_loss: 0.2512 - val_accuracy: 0.9244 - 80ms/epoch - 20ms/step
# Epoch 48/50
# 4/4 - 0s - loss: 0.4599 - accuracy: 0.8711 - val_loss: 0.2473 - val_accuracy: 0.9244 - 73ms/epoch - 18ms/step
# Epoch 49/50
# 4/4 - 0s - loss: 0.4665 - accuracy: 0.8681 - val_loss: 0.2436 - val_accuracy: 0.9244 - 61ms/epoch - 15ms/step
# Epoch 50/50
# 4/4 - 0s - loss: 0.5043 - accuracy: 0.8578 - val_loss: 0.2407 - val_accuracy: 0.9244 - 80ms/epoch - 20ms/step

# %%
# print the test accuracy
score = model1.evaluate(x_test, y_test, verbose=2)
print('Test accuracy:', score[1])
# Out:
# 8/8 - 0s - loss: 0.2407 - accuracy: 0.9244 - 31ms/epoch - 4ms/step
# Test accuracy: 0.9244444370269775

# %%
# plot the accuracy plot
plt.plot(History.history['accuracy'], 'r')
plt.plot(History.history['val_accuracy'], 'b')
plt.legend({'Train Accuracy': 'r', 'Test Accuracy':'b'})
plt.show()

# %%
# Plot training & validation loss values
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np
y_pred_prob = model1.predict(x_test)

y_pred = np.argmax(y_pred_prob, axis=1)

class_names = ['None', 'Sleep Apnea', 'Insomnia']  # Update with your class names
print(classification_report(np.argmax(y_test, axis=1), y_pred, target_names=class_names))
# Out:
# 8/8 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#         None       0.91      0.99      0.94        68
#  Sleep Apnea       0.92      0.86      0.89        70
#     Insomnia       0.94      0.93      0.94        87
#
#     accuracy                           0.92       225
#    macro avg       0.92      0.92      0.92       225
# weighted avg       0.92      0.92      0.92       225

# %%
# Generate confusion matrix
conf_matrix = confusion_matrix(np.argmax(y_test, axis=1), y_pred)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.preprocessing import label_binarize

y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

# Get predicted probabilities for each class
train_pred_prob = model1.predict(x_train)
test_pred_prob = model1.predict(x_test)

# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_train_bin[:, i], train_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
colors = ['red', 'green', 'blue']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, label=f'ROC curve (class {i+1}) - AUC = {roc_auc[i]:.2f}')

# Plot baseline
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multiclass ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 22/22 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 3ms/step

# %%
import joblib
joblib.dump(model1, 'cnn_sleep.h5')
# Out:
# ['cnn_sleep.h5']

# %%
from tensorflow.keras.layers import Flatten

# %%
model = Sequential()
model.add(Input(shape=(11,1)))
model.add(LSTM(32,return_sequences=True))
model.add(LSTM(16,return_sequences=True))
model.add(LSTM(8))
model.add(Flatten())
model.add(Dense(250, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(150, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(3, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
History_1 = model.fit(x_train, y_train, validation_data=(x_test,y_test), epochs=50, batch_size=28, verbose=2)
# Out:
# Epoch 1/50
# 25/25 - 9s - loss: 0.6363 - accuracy: 0.4489 - val_loss: 0.5339 - val_accuracy: 0.6667 - 9s/epoch - 364ms/step
# Epoch 2/50
# 25/25 - 0s - loss: 0.4792 - accuracy: 0.6133 - val_loss: 0.4066 - val_accuracy: 0.7244 - 402ms/epoch - 16ms/step
# Epoch 3/50
# 25/25 - 0s - loss: 0.3874 - accuracy: 0.7422 - val_loss: 0.3289 - val_accuracy: 0.8311 - 431ms/epoch - 17ms/step
# Epoch 4/50
# 25/25 - 0s - loss: 0.3349 - accuracy: 0.8000 - val_loss: 0.2986 - val_accuracy: 0.7600 - 398ms/epoch - 16ms/step
# Epoch 5/50
# 25/25 - 0s - loss: 0.2936 - accuracy: 0.8415 - val_loss: 0.2284 - val_accuracy: 0.8978 - 411ms/epoch - 16ms/step
# Epoch 6/50
# 25/25 - 0s - loss: 0.2807 - accuracy: 0.8459 - val_loss: 0.1882 - val_accuracy: 0.8889 - 416ms/epoch - 17ms/step
# Epoch 7/50
# 25/25 - 0s - loss: 0.2563 - accuracy: 0.8667 - val_loss: 0.1789 - val_accuracy: 0.8800 - 431ms/epoch - 17ms/step
# Epoch 8/50
# 25/25 - 0s - loss: 0.2476 - accuracy: 0.8756 - val_loss: 0.1672 - val_accuracy: 0.9333 - 391ms/epoch - 16ms/step
# Epoch 9/50
# 25/25 - 0s - loss: 0.2500 - accuracy: 0.8741 - val_loss: 0.1635 - val_accuracy: 0.9333 - 383ms/epoch - 15ms/step
# Epoch 10/50
# 25/25 - 0s - loss: 0.2572 - accuracy: 0.8578 - val_loss: 0.1721 - val_accuracy: 0.8978 - 412ms/epoch - 16ms/step
# Epoch 11/50
# 25/25 - 0s - loss: 0.2455 - accuracy: 0.8711 - val_loss: 0.1710 - val_accuracy: 0.8978 - 396ms/epoch - 16ms/step
# Epoch 12/50
# 25/25 - 0s - loss: 0.2349 - accuracy: 0.8859 - val_loss: 0.1557 - val_accuracy: 0.9200 - 398ms/epoch - 16ms/step
# Epoch 13/50
# 25/25 - 0s - loss: 0.2345 - accuracy: 0.8919 - val_loss: 0.1559 - val_accuracy: 0.9333 - 399ms/epoch - 16ms/step
# Epoch 14/50
# 25/25 - 0s - loss: 0.2297 - accuracy: 0.8919 - val_loss: 0.1513 - val_accuracy: 0.9333 - 383ms/epoch - 15ms/step
# Epoch 15/50
# 25/25 - 0s - loss: 0.2306 - accuracy: 0.8919 - val_loss: 0.1520 - val_accuracy: 0.9289 - 401ms/epoch - 16ms/step
# Epoch 16/50
# 25/25 - 0s - loss: 0.2439 - accuracy: 0.8726 - val_loss: 0.1594 - val_accuracy: 0.9333 - 399ms/epoch - 16ms/step
# Epoch 17/50
# 25/25 - 0s - loss: 0.2267 - accuracy: 0.8904 - val_loss: 0.1590 - val_accuracy: 0.9289 - 416ms/epoch - 17ms/step
# Epoch 18/50
# 25/25 - 0s - loss: 0.2293 - accuracy: 0.8904 - val_loss: 0.1472 - val_accuracy: 0.9289 - 401ms/epoch - 16ms/step
# Epoch 19/50
# 25/25 - 0s - loss: 0.2207 - accuracy: 0.8919 - val_loss: 0.1607 - val_accuracy: 0.9378 - 388ms/epoch - 16ms/step
# Epoch 20/50
# 25/25 - 0s - loss: 0.2222 - accuracy: 0.8993 - val_loss: 0.1484 - val_accuracy: 0.9333 - 401ms/epoch - 16ms/step
# Epoch 21/50
# 25/25 - 0s - loss: 0.2378 - accuracy: 0.8741 - val_loss: 0.1569 - val_accuracy: 0.9422 - 388ms/epoch - 16ms/step
# Epoch 22/50
# 25/25 - 0s - loss: 0.2199 - accuracy: 0.8993 - val_loss: 0.1447 - val_accuracy: 0.9422 - 397ms/epoch - 16ms/step
# Epoch 23/50
# 25/25 - 1s - loss: 0.2074 - accuracy: 0.8993 - val_loss: 0.1441 - val_accuracy: 0.9378 - 562ms/epoch - 22ms/step
# Epoch 24/50
# 25/25 - 1s - loss: 0.2111 - accuracy: 0.8933 - val_loss: 0.1362 - val_accuracy: 0.9378 - 612ms/epoch - 24ms/step
# Epoch 25/50
# 25/25 - 1s - loss: 0.2062 - accuracy: 0.9022 - val_loss: 0.1375 - val_accuracy: 0.9422 - 606ms/epoch - 24ms/step
# Epoch 26/50
# 25/25 - 1s - loss: 0.2077 - accuracy: 0.9022 - val_loss: 0.1484 - val_accuracy: 0.9289 - 606ms/epoch - 24ms/step
# Epoch 27/50
# 25/25 - 1s - loss: 0.2005 - accuracy: 0.9081 - val_loss: 0.1335 - val_accuracy: 0.9378 - 589ms/epoch - 24ms/step
# Epoch 28/50
# 25/25 - 1s - loss: 0.2108 - accuracy: 0.8919 - val_loss: 0.1376 - val_accuracy: 0.9378 - 655ms/epoch - 26ms/step
# Epoch 29/50
# 25/25 - 0s - loss: 0.1930 - accuracy: 0.9111 - val_loss: 0.1322 - val_accuracy: 0.9422 - 486ms/epoch - 19ms/step
# Epoch 30/50
# 25/25 - 0s - loss: 0.1954 - accuracy: 0.9067 - val_loss: 0.1354 - val_accuracy: 0.9378 - 411ms/epoch - 16ms/step
# Epoch 31/50
# 25/25 - 0s - loss: 0.2053 - accuracy: 0.8978 - val_loss: 0.1408 - val_accuracy: 0.9422 - 425ms/epoch - 17ms/step
# Epoch 32/50
# 25/25 - 0s - loss: 0.1912 - accuracy: 0.9067 - val_loss: 0.1374 - val_accuracy: 0.9378 - 433ms/epoch - 17ms/step
# Epoch 33/50
# 25/25 - 0s - loss: 0.1939 - accuracy: 0.9052 - val_loss: 0.1883 - val_accuracy: 0.8889 - 400ms/epoch - 16ms/step
# Epoch 34/50
# 25/25 - 0s - loss: 0.2037 - accuracy: 0.9081 - val_loss: 0.1346 - val_accuracy: 0.9378 - 421ms/epoch - 17ms/step
# Epoch 35/50
# 25/25 - 0s - loss: 0.1888 - accuracy: 0.9156 - val_loss: 0.1340 - val_accuracy: 0.9378 - 412ms/epoch - 16ms/step
# Epoch 36/50
# 25/25 - 0s - loss: 0.1831 - accuracy: 0.9111 - val_loss: 0.1307 - val_accuracy: 0.9422 - 399ms/epoch - 16ms/step
# Epoch 37/50
# 25/25 - 0s - loss: 0.1818 - accuracy: 0.9156 - val_loss: 0.1384 - val_accuracy: 0.9378 - 412ms/epoch - 16ms/step
# Epoch 38/50
# 25/25 - 0s - loss: 0.1864 - accuracy: 0.9141 - val_loss: 0.1306 - val_accuracy: 0.9378 - 387ms/epoch - 15ms/step
# Epoch 39/50
# 25/25 - 0s - loss: 0.1818 - accuracy: 0.9185 - val_loss: 0.1333 - val_accuracy: 0.9378 - 423ms/epoch - 17ms/step
# Epoch 40/50
# 25/25 - 0s - loss: 0.1733 - accuracy: 0.9244 - val_loss: 0.1230 - val_accuracy: 0.9422 - 412ms/epoch - 16ms/step
# Epoch 41/50
# 25/25 - 0s - loss: 0.2037 - accuracy: 0.9007 - val_loss: 0.1385 - val_accuracy: 0.9422 - 420ms/epoch - 17ms/step
# Epoch 42/50
# 25/25 - 0s - loss: 0.1809 - accuracy: 0.9215 - val_loss: 0.1255 - val_accuracy: 0.9422 - 439ms/epoch - 18ms/step
# Epoch 43/50
# 25/25 - 0s - loss: 0.1698 - accuracy: 0.9244 - val_loss: 0.1240 - val_accuracy: 0.9378 - 396ms/epoch - 16ms/step
# Epoch 44/50
# 25/25 - 0s - loss: 0.1710 - accuracy: 0.9200 - val_loss: 0.1198 - val_accuracy: 0.9422 - 440ms/epoch - 18ms/step
# Epoch 45/50
# 25/25 - 0s - loss: 0.1703 - accuracy: 0.9259 - val_loss: 0.1241 - val_accuracy: 0.9422 - 398ms/epoch - 16ms/step
# Epoch 46/50
# 25/25 - 0s - loss: 0.1678 - accuracy: 0.9259 - val_loss: 0.1247 - val_accuracy: 0.9422 - 408ms/epoch - 16ms/step
# Epoch 47/50
# 25/25 - 0s - loss: 0.1689 - accuracy: 0.9230 - val_loss: 0.1275 - val_accuracy: 0.9422 - 431ms/epoch - 17ms/step
# Epoch 48/50
# 25/25 - 0s - loss: 0.1627 - accuracy: 0.9274 - val_loss: 0.1185 - val_accuracy: 0.9422 - 395ms/epoch - 16ms/step
# Epoch 49/50
# 25/25 - 0s - loss: 0.1649 - accuracy: 0.9259 - val_loss: 0.1146 - val_accuracy: 0.9422 - 421ms/epoch - 17ms/step
# Epoch 50/50
# 25/25 - 0s - loss: 0.1651 - accuracy: 0.9274 - val_loss: 0.1184 - val_accuracy: 0.9422 - 386ms/epoch - 15ms/step

# %%
# plot the accuracy plot
plt.plot(History_1.history['accuracy'], 'r')
plt.plot(History_1.history['val_accuracy'], 'b')
plt.legend({'Train Accuracy': 'r', 'Test Accuracy':'b'})
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(History_1.history['loss'])
plt.plot(History_1.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation accuracy values
plt.plot(History_1.history['accuracy'])
plt.plot(History_1.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

train_fpr, train_tpr, _ = roc_curve(y_train_bin[:, 1], train_pred_prob[:, 1])
test_fpr, test_tpr, _ = roc_curve(y_test_bin[:, 1], test_pred_prob[:, 1])

train_auc = auc(train_fpr, train_tpr)
test_auc = auc(test_fpr, test_tpr)

plt.figure(figsize=(10, 6))
plt.plot(train_fpr, train_tpr, label=f'Train AUC = {train_auc:.2f}')
plt.plot(test_fpr, test_tpr, label=f'Test AUC = {test_auc:.2f}')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
y_pred_prob = model.predict(x_test)

y_pred = np.argmax(y_pred_prob, axis=1)

class_names = ['None', 'Sleep Apnea', 'Insomnia']  # Update with your class names
print(classification_report(np.argmax(y_test, axis=1), y_pred, target_names=class_names))
# Out:
# 8/8 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#         None       0.91      1.00      0.95        68
#  Sleep Apnea       0.92      0.93      0.92        70
#     Insomnia       1.00      0.91      0.95        87
#
#     accuracy                           0.94       225
#    macro avg       0.94      0.95      0.94       225
# weighted avg       0.95      0.94      0.94       225

# %%
# Generate confusion matrix
conf_matrix = confusion_matrix(np.argmax(y_test, axis=1), y_pred)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import joblib
joblib.dump(model, 'lstm_sleep.h5')
# Out:
# ['lstm_sleep.h5']
